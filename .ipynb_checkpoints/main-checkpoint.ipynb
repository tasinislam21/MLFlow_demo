# %%
import mlflow
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# ### Make sure to run 'mlflow ui' in terminal to start MLFlow

# %%
mlflow.set_tracking_uri('http://localhost:5000')
mlflow.set_experiment("house_price_predictor") # creates new experiment

# %%
data = fetch_california_housing(as_frame=True)
target = data.target
data = data.data
data['cost'] = target

# %%
data

# %%
df_ml_input = data.drop(['cost'], axis=1)
df_ml_output = data['cost']
X_train, X_test, y_train, y_test = train_test_split(data.drop(['cost'], axis=1), data['cost'], test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
import optuna
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 1200, step=50),
        "max_depth": trial.suggest_int("max_depth", 1, 7),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.5),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
    }
    model = xgb.XGBRegressor(**params)

    with mlflow.start_run(nested=True):
        scores = cross_val_score(
            model,
            df_ml_input,
            df_ml_output,
            cv=cv,
            scoring="neg_root_mean_squared_error",
            n_jobs=-1
        )
        rmse = -scores.mean()
        mlflow.log_params(params)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_param("trial_number", trial.number)
        return rmse

# %%
with mlflow.start_run(run_name="XGBoost hyperparameter finetuning"):
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=30, show_progress_bar=True)

# %%
best_model = xgb.XGBRegressor(**study.best_params)
best_model.fit(X_train, y_train)
predicted_values_xg = best_model.predict(X_test)

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np

with mlflow.start_run(run_name="final_model"):
    mlflow.log_params(study.best_params)
    mlflow.xgboost.log_model(best_model, "XGBRegressor_house_price")
    # Residuals
    res_xg = y_test.values.ravel() - predicted_values_xg
    
    # Create side-by-side plots
    fig, axes = plt.subplots(1, 1, figsize=(6, 6))
    
    axes.scatter(y_test, res_xg, alpha=0.5)
    axes.axhline(0, color='red', linestyle='--')
    axes.set_xlabel("Actual values")
    axes.set_ylabel("Residuals")
    axes.set_title("Residual Plot")
    
    mlflow.log_figure(fig, "residual_plot.png")
    plt.close(fig)
    
    fig, axs = plt.subplots(1, 1, figsize=(14, 6))
    (osm, osr), (slope, intercept, r) = stats.probplot(
        np.asarray(res_xg).ravel(), dist="norm"
    )
    axs.plot(osm, osr, 'o')
    axs.plot(osm, slope * osm + intercept, 'r--')
    axs.set_title("QQ Plot")
    
    mlflow.log_figure(fig, "qq.png")
    plt.close(fig)

# %% [markdown]
# ### Time to deploy and serve the model.
#
# In MLFlow, remember to register the model in the model registry and give it a name.
#
# Go to terminal -> export MLFLOW_TRACKING_URI=http://localhost:5000 -> mlflow models serve -m models:/(registerd_nodel_name)/1 -p 5001

# %%
payload = {
    "dataframe_split": X_test.iloc[[0]].to_dict(orient="split")
}
payload

# %%
import requests
import pandas as pd
import json

url = "http://localhost:5001/invocations"

payload = {
    "dataframe_split": X_test.iloc[[0]].to_dict(orient="split")
}

response = requests.post(url, json=payload)
print(response.json())
